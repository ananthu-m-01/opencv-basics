# %%
import cv2
import matplotlib.pyplot as plt
import os

image_path = os.path.join("../images", "salah.jpg")
image = cv2.imread(image_path)

# function to display the image
def show_image(title,img,cmap=None):
    plt.figure(figsize=(6,6))
    plt.imshow(img,cmap=cmap)
    plt.title(title)
    plt.axis("off")
    plt.show()

show_image("Original image (BGR)",image)

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Function to display individual channels
def show_channels(title, img, channel_names, color_space="RGB"):
    channels = cv2.split(img)
    
    for i, channel in enumerate(channels):
        cmap = "gray" if color_space != "HSV" else None  # HSV can be displayed as-is
        show_image(f"{title} - {channel_names[i]}", channel, cmap=cmap)

# Show HSV image converted back to RGB
show_image("HSV (Converted to RGB)", cv2.cvtColor(image_hsv, cv2.COLOR_HSV2RGB))

# Show individual HSV channels
show_channels("HSV Channels", image_hsv, ["Hue", "Saturation", "Value"], color_space="HSV")
